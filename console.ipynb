# %%
# %pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-0.4.8-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-0.3.63-py3-none-any.whl.metadata (5.8 kB)
# Collecting langgraph-checkpoint>=2.0.26 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.26-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-prebuilt>=0.2.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.2.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk>=0.1.42 (from langgraph)
#   Downloading langgraph_sdk-0.1.70-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in d:\devenv\python\lib\site-packages (from langgraph) (2.10.6)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting langsmith<0.4,>=0.1.126 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.3.44-py3-none-any.whl.metadata (15 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core>=0.1->langgraph)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core>=0.1->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting PyYAML>=5.3 (from langchain-core>=0.1->langgraph)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging<25,>=23.2 in d:\devenv\python\lib\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\devenv\python\lib\site-packages (from langchain-core>=0.1->langgraph) (4.12.2)
# Collecting ormsgpack<2.0.0,>=1.8.0 (from langgraph-checkpoint>=2.0.26->langgraph)
#   Downloading ormsgpack-1.10.0-cp312-cp312-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: httpx>=0.25.2 in d:\devenv\python\lib\site-packages (from langgraph-sdk>=0.1.42->langgraph) (0.28.1)
# Collecting orjson>=3.10.1 (from langgraph-sdk>=0.1.42->langgraph)
#   Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\devenv\python\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\devenv\python\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.27.2)
# Requirement already satisfied: anyio in d:\devenv\python\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (4.8.0)
# Requirement already satisfied: certifi in d:\devenv\python\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\devenv\python\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in d:\devenv\python\lib\site-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\devenv\python\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (0.14.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests<3,>=2 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\devenv\python\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\devenv\python\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\devenv\python\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (1.3.1)
# Downloading langgraph-0.4.8-py3-none-any.whl (152 kB)
# Downloading langchain_core-0.3.63-py3-none-any.whl (438 kB)
# Downloading langgraph_checkpoint-2.0.26-py3-none-any.whl (44 kB)
# Downloading langgraph_prebuilt-0.2.2-py3-none-any.whl (23 kB)
# Downloading langgraph_sdk-0.1.70-py3-none-any.whl (49 kB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.3.44-py3-none-any.whl (361 kB)
# Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl (134 kB)
# Downloading ormsgpack-1.10.0-cp312-cp312-win_amd64.whl (121 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: xxhash, tenacity, PyYAML, ormsgpack, orjson, jsonpointer, jsonpatch, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed PyYAML-6.0.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.63 langgraph-0.4.8 langgraph-checkpoint-2.0.26 langgraph-prebuilt-0.2.2 langgraph-sdk-0.1.70 langsmith-0.3.44 orjson-3.10.18 ormsgpack-1.10.0 tenacity-9.1.2 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\admin\appdata\roaming\python\python312\site-packages (9.3.0)
# Requirement already satisfied: colorama in d:\devenv\python\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\devenv\python\lib\site-packages (from IPython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\devenv\python\lib\site-packages (from IPython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from IPython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: wcwidth in d:\devenv\python\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack_data->IPython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack_data->IPython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack_data->IPython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.19-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.63 in d:\devenv\python\lib\site-packages (from langchain_openai) (0.3.63)
# Collecting openai<2.0.0,>=1.68.2 (from langchain_openai)
#   Downloading openai-1.83.0-py3-none-any.whl.metadata (25 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.9.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.3.44)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (4.12.2)
# Requirement already satisfied: pydantic>=2.7.4 in d:\devenv\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\devenv\python\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.68.2->langchain_openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\devenv\python\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.68.2->langchain_openai)
#   Downloading jiter-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in d:\devenv\python\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\devenv\python\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in d:\devenv\python\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in d:\devenv\python\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\devenv\python\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain_openai) (3.10)
# Requirement already satisfied: certifi in d:\devenv\python\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\devenv\python\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\devenv\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\devenv\python\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.63->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\devenv\python\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\devenv\python\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\devenv\python\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\devenv\python\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\devenv\python\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.3.0)
# Requirement already satisfied: colorama in d:\devenv\python\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain_openai) (0.4.6)
# Downloading langchain_openai-0.3.19-py3-none-any.whl (64 kB)
# Downloading openai-1.83.0-py3-none-any.whl (723 kB)
#    ---------------------------------------- 0.0/723.4 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/723.4 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 723.4/723.4 kB 4.2 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp312-cp312-win_amd64.whl (894 kB)
#    ---------------------------------------- 0.0/894.9 kB ? eta -:--:--
#    ---------------------------------------- 894.9/894.9 kB 6.8 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp312-cp312-win_amd64.whl (206 kB)
# Installing collected packages: jiter, distro, tiktoken, openai, langchain_openai
# Successfully installed distro-1.9.0 jiter-0.10.0 langchain_openai-0.3.19 openai-1.83.0 tiktoken-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 可视化 LangGraph 状态图的 Notebook 脚本

from core.graph import workflow

from IPython.display import Image, display


try:
    display(Image(workflow.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
